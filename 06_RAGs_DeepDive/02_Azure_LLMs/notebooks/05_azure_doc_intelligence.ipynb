# %% [markdown]
# # Azure Document Intelligence

# %% [markdown]
# ## PDF to Markdown
#
# Sources:
#
# - [sample_analyze_documents_output_in_markdown.py](https://github.com/Azure/azure-sdk-for-python/blob/main/sdk/documentintelligence/azure-ai-documentintelligence/samples/sample_analyze_documents_output_in_markdown.py)
# - [DocumentIntelligenceClient Class](https://learn.microsoft.com/en-us/python/api/azure-ai-documentintelligence/azure.ai.documentintelligence.documentintelligenceclient?view=azure-python#azure-ai-documentintelligence-documentintelligenceclient-begin-analyze-document)
# - [AnalyzeDocumentRequest Class](https://learn.microsoft.com/en-us/python/api/azure-ai-documentintelligence/azure.ai.documentintelligence.models.analyzedocumentrequest?view=azure-python)

# %%
import os
from os.path import dirname
from dotenv import load_dotenv

from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import (
    AnalyzeDocumentRequest, DocumentContentFormat, AnalyzeResult
)

# Load environment variables
current_dir = os.path.abspath(".")
root_dir = dirname(current_dir)
env_file = os.path.join(current_dir, '.env')
load_dotenv(env_file, override=True)

def pdf2markdown(file_path: str):
    # Get the endpoint and key from the environment
    endpoint = os.environ["AZURE_DOCUMENTINTELLIGENCE_ENDPOINT"]
    key = os.environ["AZURE_DOCUMENTINTELLIGENCE_API_KEY"]
    # NOTE: we could also use a URL instead of the local file path
    #url = "https://github.com/mxagar/generative_ai_udacity/blob/main/06_RAGs_DeepDive/02_Azure_LLMs/literature/Lewis_RAG_2021_one_page.pdf"

    client = DocumentIntelligenceClient(endpoint=endpoint, credential=AzureKeyCredential(key))
    with open(file_path, "rb") as file_stream:
        poller = client.begin_analyze_document(
            model_id="prebuilt-layout",
            body=file_stream,  # Pass the local file stream
            #body=AnalyzeDocumentRequest(url_source=url), # Use this line to analyze a document from a URL
            output_content_format=DocumentContentFormat.MARKDOWN,
            content_type="application/pdf",  # Explicitly specify content type
        )
        result: AnalyzeResult = poller.result()

    print(f"Here's the full content in format {result.content_format}:\n")
    print(result.content)

# %%
pdf2markdown("../literature/Lewis_RAG_2021_one_page.pdf")
# Out:
# Here's the full content in format markdown:
#
# # Retrieval-Augmented Generation for Knowledge-Intensive NLP Tasks
#
# Patrick Lewis++, Ethan Perez*,
#
# Aleksandra Piktust, Fabio Petroni+, Vladimir Karpukhint, Naman Goyal+, Heinrich Küttler*,
# Mike Lewist, Wen-tau Yiht, Tim Rocktäschel++, Sebastian Riedel++, Douwe Kielat
# +Facebook AI Research; #University College London; * New York University;
# plewis@fb.com
#
#
# ## Abstract
#
# Large pre-trained language models have been shown to store factual knowledge
# in their parameters, and achieve state-of-the-art results when fine-tuned on down-
# stream NLP tasks. However, their ability to access and precisely manipulate knowl-
# edge is still limited, and hence on knowledge-intensive tasks, their performance
# lags behind task-specific architectures. Additionally, providing provenance for their
# decisions and updating their world knowledge remain open research problems. Pre-
# trained models with a differentiable access mechanism to explicit non-parametric
# memory have so far been only investigated for extractive downstream tasks. We
# explore a general-purpose fine-tuning recipe for retrieval-augmented generation
# (RAG) - models which combine pre-trained parametric and non-parametric mem-
# ory for language generation. We introduce RAG models where the parametric
# memory is a pre-trained seq2seq model and the non-parametric memory is a dense
# vector index of Wikipedia, accessed with a pre-trained neural retriever. We com-
# pare two RAG formulations, one which conditions on the same retrieved passages
# across the whole generated sequence, and another which can use different passages
# per token. We fine-tune and evaluate our models on a wide range of knowledge-
# intensive NLP tasks and set the state of the art on three open domain QA tasks,
# outperforming parametric seq2seq models and task-specific retrieve-and-extract
# architectures. For language generation tasks, we find that RAG models generate
# more specific, diverse and factual language than a state-of-the-art parametric-only
# seq2seq baseline.
#
#
# ## 1 Introduction
#
# Pre-trained neural language models have been shown to learn a substantial amount of in-depth knowl-
# edge from data [47]. They can do so without any access to an external memory, as a parameterized
# implicit knowledge base [51, 52]. While this development is exciting, such models do have down-
# sides: They cannot easily expand or revise their memory, can't straightforwardly provide insight into
# their predictions, and may produce "hallucinations" [38]. Hybrid models that combine parametric
# memory with non-parametric (i.e., retrieval-based) memories [20, 26, 48] can address some of these
# issues because knowledge can be directly revised and expanded, and accessed knowledge can be
# inspected and interpreted. REALM [20] and ORQA [31], two recently introduced models that
# combine masked language models [8] with a differentiable retriever, have shown promising results,
#
# <!-- PageFooter="arXiv:2005.11401v4 [cs.CL] 12 Apr 2021" -->

# %% [markdown]
# ### Layout Analysis

# %% [markdown]
# - [AnalyzeResult Class](https://learn.microsoft.com/en-us/python/api/azure-ai-formrecognizer/azure.ai.formrecognizer.analyzeresult?view=azure-python)
# - [sample_analyze_layout.py](https://github.com/Azure/azure-sdk-for-python/blob/main/sdk/documentintelligence/azure-ai-documentintelligence/samples/sample_analyze_layout.py)

# %%
import os
from os.path import dirname
from dotenv import load_dotenv

from azure.core.credentials import AzureKeyCredential
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import AnalyzeResult

# Load environment variables
current_dir = os.path.abspath(".")
root_dir = dirname(current_dir)
env_file = os.path.join(current_dir, '.env')
load_dotenv(env_file, override=True)


def analyze_layout(file_path: str, display: bool = True):
    def _in_span(word, spans):
        for span in spans:
            if word.span.offset >= span.offset and (word.span.offset + word.span.length) <= (span.offset + span.length):
                return True
        return False

    def _format_polygon(polygon):
        if not polygon:
            return "N/A"
        return ", ".join([f"[{polygon[i]}, {polygon[i + 1]}]" for i in range(0, len(polygon), 2)])

    endpoint = os.environ["AZURE_DOCUMENTINTELLIGENCE_ENDPOINT"]
    key = os.environ["AZURE_DOCUMENTINTELLIGENCE_API_KEY"]

    client = DocumentIntelligenceClient(endpoint=endpoint, credential=AzureKeyCredential(key))
    with open(file_path, "rb") as f:
        poller = client.begin_analyze_document("prebuilt-layout", body=f)
    result: AnalyzeResult = poller.result()

    if display:
        if result.styles and any([style.is_handwritten for style in result.styles]):
            print("Document contains handwritten content")
        else:
            print("Document does not contain handwritten content")

        for page in result.pages:
            print(f"----Analyzing layout from page #{page.page_number}----")
            print(f"Page has width: {page.width} and height: {page.height}, measured with unit: {page.unit}")

            if page.lines:
                for line_idx, line in enumerate(page.lines):
                    words = []
                    if page.words:
                        for word in page.words:
                            print(f"......Word '{word.content}' has a confidence of {word.confidence}")
                            if _in_span(word, line.spans):
                                words.append(word)
                    print(
                        f"...Line # {line_idx} has word count {len(words)} and text '{line.content}' "
                        f"within bounding polygon '{_format_polygon(line.polygon)}'"
                    )

            if page.selection_marks:
                for selection_mark in page.selection_marks:
                    print(
                        f"Selection mark is '{selection_mark.state}' within bounding polygon "
                        f"'{_format_polygon(selection_mark.polygon)}' and has a confidence of {selection_mark.confidence}"
                    )

        if result.paragraphs:
            print(f"----Detected #{len(result.paragraphs)} paragraphs in the document----")
            # Sort all paragraphs by span's offset to read in the right order.
            result.paragraphs.sort(key=lambda p: (p.spans.sort(key=lambda s: s.offset), p.spans[0].offset))
            print("-----Print sorted paragraphs-----")
            for paragraph in result.paragraphs:
                if not paragraph.bounding_regions:
                    print(f"Found paragraph with role: '{paragraph.role}' within N/A bounding region")
                else:
                    print(f"Found paragraph with role: '{paragraph.role}' within")
                    print(
                        ", ".join(
                            f" Page #{region.page_number}: {_format_polygon(region.polygon)} bounding region"
                            for region in paragraph.bounding_regions
                        )
                    )
                print(f"...with content: '{paragraph.content}'")
                print(f"...with offset: {paragraph.spans[0].offset} and length: {paragraph.spans[0].length}")

        if result.tables:
            for table_idx, table in enumerate(result.tables):
                print(f"Table # {table_idx} has {table.row_count} rows and " f"{table.column_count} columns")
                if table.bounding_regions:
                    for region in table.bounding_regions:
                        print(
                            f"Table # {table_idx} location on page: {region.page_number} is {_format_polygon(region.polygon)}"
                        )
                for cell in table.cells:
                    print(f"...Cell[{cell.row_index}][{cell.column_index}] has text '{cell.content}'")
                    if cell.bounding_regions:
                        for region in cell.bounding_regions:
                            print(
                                f"...content on page {region.page_number} is within bounding polygon '{_format_polygon(region.polygon)}'"
                            )

        print("----------------------------------------")
    
    return result

# %%
result = analyze_layout("../literature/Lewis_RAG_2021_one_page.pdf")
# Out:
# Document does not contain handwritten content
# ----Analyzing layout from page #1----
# Page has width: 8.5 and height: 11.0, measured with unit: inch
# ......Word 'Retrieval-Augmented' has a confidence of 0.992
# ......Word 'Generation' has a confidence of 0.995
# ......Word 'for' has a confidence of 0.999
# ......Word 'Knowledge-Intensive' has a confidence of 0.992
# ......Word 'NLP' has a confidence of 0.989
# ......Word 'Tasks' has a confidence of 0.995
# ......Word 'Patrick' has a confidence of 0.995
# ......Word 'Lewis++,' has a confidence of 0.574
# ......Word 'Ethan' has a confidence of 0.997
# ......Word 'Perez*,' has a confidence of 0.962
# ......Word 'Aleksandra' has a confidence of 0.993
# ......Word 'Piktust,' has a confidence of 0.646
# ......Word 'Fabio' has a confidence of 0.997
# ......Word 'Petroni+,' has a confidence of 0.605
# ......Word 'Vladimir' has a confidence of 0.993
# ......Word 'Karpukhint,' has a confidence of 0.681
# ......Word 'Naman' has a confidence of 0.997
# ......Word 'Goyal+,' has a confidence of 0.549
# ......Word 'Heinrich' has a confidence of 0.996
# ......Word 'Küttler*,' has a confidence of 0.595
# ......Word 'Mike' has a confidence of 0.992
# ......Word 'Lewist,' has a confidence of 0.862
# ......Word 'Wen-tau' has a confidence of 0.994
# ......Word 'Yiht,' has a confidence of 0.662
# ......Word 'Tim' has a confidence of 0.998
# ......Word 'Rocktäschel++,' has a confidence of 0.593
# ......Word 'Sebastian' has a confidence of 0.994
# ......Word 'Riedel++,' has a confidence of 0.561
# ......Word 'Douwe' has a confidence of 0.995
# ......Word 'Kielat' has a confidence of 0.791
# ......Word '+Facebook' has a confidence of 0.288
# ......Word 'AI' has a confidence of 0.921
# ......Word 'Research;' has a confidence of 0.999
# ......Word '#University' has a confidence of 0.71
# ......Word 'College' has a confidence of 1.0
# ......Word 'London;' has a confidence of 1.0
# ......Word '*' has a confidence of 1.0
# ......Word 'New' has a confidence of 1.0
# ......Word 'York' has a confidence of 1.0
# ......Word 'University;' has a confidence of 0.999
# ......Word 'plewis@fb.com' has a confidence of 0.99
# ......Word 'Abstract' has a confidence of 0.995
# ......Word 'Large' has a confidence of 0.998
# ......Word 'pre-trained' has a confidence of 0.993
# ......Word 'language' has a confidence of 0.996
# ......Word 'models' has a confidence of 0.999
# ......Word 'have' has a confidence of 0.992
# ......Word 'been' has a confidence of 0.989
# ......Word 'shown' has a confidence of 0.998
# ......Word 'to' has a confidence of 0.999
# ......Word 'store' has a confidence of 0.998
# ......Word 'factual' has a confidence of 0.997
# ......Word 'knowledge' has a confidence of 0.996
# ......Word 'in' has a confidence of 0.998
# ......Word 'their' has a confidence of 0.998
# ......Word 'parameters,' has a confidence of 0.994
# ......Word 'and' has a confidence of 0.999
# ......Word 'achieve' has a confidence of 0.998
# ......Word 'state-of-the-art' has a confidence of 0.993
# ......Word 'results' has a confidence of 0.998
# ......Word 'when' has a confidence of 0.992
# ......Word 'fine-tuned' has a confidence of 0.995
# ......Word 'on' has a confidence of 0.999
# ......Word 'down-' has a confidence of 0.998
# ......Word 'stream' has a confidence of 0.963
# ......Word 'NLP' has a confidence of 0.997
# ......Word 'tasks.' has a confidence of 0.997
# ......Word 'However,' has a confidence of 0.995
# ......Word 'their' has a confidence of 0.997
# ......Word 'ability' has a confidence of 0.998
# ......Word 'to' has a confidence of 0.999
# ......Word 'access' has a confidence of 0.998
# ......Word 'and' has a confidence of 0.996
# ......Word 'precisely' has a confidence of 0.995
# ......Word 'manipulate' has a confidence of 0.996
# ......Word 'knowl-' has a confidence of 0.992
# ......Word 'edge' has a confidence of 0.992
# ......Word 'is' has a confidence of 0.999
# ......Word 'still' has a confidence of 0.998
# ......Word 'limited,' has a confidence of 0.994
# ......Word 'and' has a confidence of 0.999
# ......Word 'hence' has a confidence of 0.998
# ......Word 'on' has a confidence of 0.999
# ......Word 'knowledge-intensive' has a confidence of 0.993
# ......Word 'tasks,' has a confidence of 0.996
# ......Word 'their' has a confidence of 0.998
# ......Word 'performance' has a confidence of 0.993
# ......Word 'lags' has a confidence of 0.992
# ......Word 'behind' has a confidence of 0.995
# ......Word 'task-specific' has a confidence of 0.992
# ......Word 'architectures.' has a confidence of 0.992
# ......Word 'Additionally,' has a confidence of 0.992
# ......Word 'providing' has a confidence of 0.995
# ......Word 'provenance' has a confidence of 0.995
# ......Word 'for' has a confidence of 0.999
# ......Word 'their' has a confidence of 0.996
# ......Word 'decisions' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'updating' has a confidence of 0.997
# ......Word 'their' has a confidence of 0.998
# ......Word 'world' has a confidence of 0.998
# ......Word 'knowledge' has a confidence of 0.996
# ......Word 'remain' has a confidence of 0.998
# ......Word 'open' has a confidence of 0.992
# ......Word 'research' has a confidence of 0.995
# ......Word 'problems.' has a confidence of 0.995
# ......Word 'Pre-' has a confidence of 0.988
# ......Word 'trained' has a confidence of 0.995
# ......Word 'models' has a confidence of 0.995
# ......Word 'with' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.995
# ......Word 'differentiable' has a confidence of 0.994
# ......Word 'access' has a confidence of 0.997
# ......Word 'mechanism' has a confidence of 0.996
# ......Word 'to' has a confidence of 0.999
# ......Word 'explicit' has a confidence of 0.993
# ......Word 'non-parametric' has a confidence of 0.993
# ......Word 'memory' has a confidence of 0.998
# ......Word 'have' has a confidence of 0.992
# ......Word 'so' has a confidence of 0.998
# ......Word 'far' has a confidence of 0.998
# ......Word 'been' has a confidence of 0.989
# ......Word 'only' has a confidence of 0.992
# ......Word 'investigated' has a confidence of 0.995
# ......Word 'for' has a confidence of 0.999
# ......Word 'extractive' has a confidence of 0.995
# ......Word 'downstream' has a confidence of 0.995
# ......Word 'tasks.' has a confidence of 0.995
# ......Word 'We' has a confidence of 0.998
# ......Word 'explore' has a confidence of 0.996
# ......Word 'a' has a confidence of 0.995
# ......Word 'general-purpose' has a confidence of 0.992
# ......Word 'fine-tuning' has a confidence of 0.992
# ......Word 'recipe' has a confidence of 0.998
# ......Word 'for' has a confidence of 0.999
# ......Word 'retrieval-augmented' has a confidence of 0.992
# ......Word 'generation' has a confidence of 0.995
# ......Word '(RAG)' has a confidence of 0.996
# ......Word '-' has a confidence of 0.992
# ......Word 'models' has a confidence of 0.998
# ......Word 'which' has a confidence of 0.999
# ......Word 'combine' has a confidence of 0.997
# ......Word 'pre-trained' has a confidence of 0.995
# ......Word 'parametric' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'non-parametric' has a confidence of 0.992
# ......Word 'mem-' has a confidence of 0.992
# ......Word 'ory' has a confidence of 0.992
# ......Word 'for' has a confidence of 0.995
# ......Word 'language' has a confidence of 0.995
# ......Word 'generation.' has a confidence of 0.992
# ......Word 'We' has a confidence of 0.998
# ......Word 'introduce' has a confidence of 0.993
# ......Word 'RAG' has a confidence of 0.997
# ......Word 'models' has a confidence of 0.996
# ......Word 'where' has a confidence of 0.994
# ......Word 'the' has a confidence of 0.999
# ......Word 'parametric' has a confidence of 0.993
# ......Word 'memory' has a confidence of 0.995
# ......Word 'is' has a confidence of 0.987
# ......Word 'a' has a confidence of 0.994
# ......Word 'pre-trained' has a confidence of 0.992
# ......Word 'seq2seq' has a confidence of 0.992
# ......Word 'model' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'the' has a confidence of 0.999
# ......Word 'non-parametric' has a confidence of 0.992
# ......Word 'memory' has a confidence of 0.998
# ......Word 'is' has a confidence of 0.998
# ......Word 'a' has a confidence of 0.995
# ......Word 'dense' has a confidence of 0.997
# ......Word 'vector' has a confidence of 0.995
# ......Word 'index' has a confidence of 0.994
# ......Word 'of' has a confidence of 0.998
# ......Word 'Wikipedia,' has a confidence of 0.993
# ......Word 'accessed' has a confidence of 0.996
# ......Word 'with' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.995
# ......Word 'pre-trained' has a confidence of 0.993
# ......Word 'neural' has a confidence of 0.994
# ......Word 'retriever.' has a confidence of 0.992
# ......Word 'We' has a confidence of 0.999
# ......Word 'com-' has a confidence of 0.992
# ......Word 'pare' has a confidence of 0.989
# ......Word 'two' has a confidence of 0.998
# ......Word 'RAG' has a confidence of 0.998
# ......Word 'formulations,' has a confidence of 0.992
# ......Word 'one' has a confidence of 0.999
# ......Word 'which' has a confidence of 0.999
# ......Word 'conditions' has a confidence of 0.995
# ......Word 'on' has a confidence of 0.999
# ......Word 'the' has a confidence of 0.992
# ......Word 'same' has a confidence of 0.992
# ......Word 'retrieved' has a confidence of 0.994
# ......Word 'passages' has a confidence of 0.994
# ......Word 'across' has a confidence of 0.997
# ......Word 'the' has a confidence of 0.999
# ......Word 'whole' has a confidence of 0.997
# ......Word 'generated' has a confidence of 0.995
# ......Word 'sequence,' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'another' has a confidence of 0.998
# ......Word 'which' has a confidence of 0.998
# ......Word 'can' has a confidence of 0.998
# ......Word 'use' has a confidence of 0.998
# ......Word 'different' has a confidence of 0.994
# ......Word 'passages' has a confidence of 0.995
# ......Word 'per' has a confidence of 0.997
# ......Word 'token.' has a confidence of 0.998
# ......Word 'We' has a confidence of 0.989
# ......Word 'fine-tune' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'evaluate' has a confidence of 0.997
# ......Word 'our' has a confidence of 0.998
# ......Word 'models' has a confidence of 0.997
# ......Word 'on' has a confidence of 0.999
# ......Word 'a' has a confidence of 0.996
# ......Word 'wide' has a confidence of 0.992
# ......Word 'range' has a confidence of 0.998
# ......Word 'of' has a confidence of 0.998
# ......Word 'knowledge-' has a confidence of 0.995
# ......Word 'intensive' has a confidence of 0.994
# ......Word 'NLP' has a confidence of 0.995
# ......Word 'tasks' has a confidence of 0.996
# ......Word 'and' has a confidence of 0.998
# ......Word 'set' has a confidence of 0.997
# ......Word 'the' has a confidence of 0.999
# ......Word 'state' has a confidence of 0.997
# ......Word 'of' has a confidence of 0.992
# ......Word 'the' has a confidence of 0.999
# ......Word 'art' has a confidence of 0.998
# ......Word 'on' has a confidence of 0.999
# ......Word 'three' has a confidence of 0.996
# ......Word 'open' has a confidence of 0.989
# ......Word 'domain' has a confidence of 0.994
# ......Word 'QA' has a confidence of 0.992
# ......Word 'tasks,' has a confidence of 0.992
# ......Word 'outperforming' has a confidence of 0.993
# ......Word 'parametric' has a confidence of 0.992
# ......Word 'seq2seq' has a confidence of 0.987
# ......Word 'models' has a confidence of 0.994
# ......Word 'and' has a confidence of 0.998
# ......Word 'task-specific' has a confidence of 0.992
# ......Word 'retrieve-and-extract' has a confidence of 0.992
# ......Word 'architectures.' has a confidence of 0.992
# ......Word 'For' has a confidence of 0.998
# ......Word 'language' has a confidence of 0.994
# ......Word 'generation' has a confidence of 0.995
# ......Word 'tasks,' has a confidence of 0.993
# ......Word 'we' has a confidence of 0.998
# ......Word 'find' has a confidence of 0.992
# ......Word 'that' has a confidence of 0.988
# ......Word 'RAG' has a confidence of 0.997
# ......Word 'models' has a confidence of 0.997
# ......Word 'generate' has a confidence of 0.994
# ......Word 'more' has a confidence of 0.992
# ......Word 'specific,' has a confidence of 0.992
# ......Word 'diverse' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.995
# ......Word 'factual' has a confidence of 0.994
# ......Word 'language' has a confidence of 0.996
# ......Word 'than' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.995
# ......Word 'state-of-the-art' has a confidence of 0.992
# ......Word 'parametric-only' has a confidence of 0.993
# ......Word 'seq2seq' has a confidence of 0.977
# ......Word 'baseline.' has a confidence of 0.996
# ......Word '1' has a confidence of 0.997
# ......Word 'Introduction' has a confidence of 0.993
# ......Word 'Pre-trained' has a confidence of 0.995
# ......Word 'neural' has a confidence of 0.998
# ......Word 'language' has a confidence of 0.998
# ......Word 'models' has a confidence of 0.998
# ......Word 'have' has a confidence of 0.992
# ......Word 'been' has a confidence of 0.992
# ......Word 'shown' has a confidence of 0.998
# ......Word 'to' has a confidence of 0.999
# ......Word 'learn' has a confidence of 0.998
# ......Word 'a' has a confidence of 0.996
# ......Word 'substantial' has a confidence of 0.995
# ......Word 'amount' has a confidence of 0.999
# ......Word 'of' has a confidence of 0.992
# ......Word 'in-depth' has a confidence of 0.997
# ......Word 'knowl-' has a confidence of 0.993
# ......Word 'edge' has a confidence of 0.992
# ......Word 'from' has a confidence of 0.992
# ......Word 'data' has a confidence of 0.992
# ......Word '[47].' has a confidence of 0.975
# ......Word 'They' has a confidence of 0.992
# ......Word 'can' has a confidence of 0.999
# ......Word 'do' has a confidence of 0.999
# ......Word 'so' has a confidence of 0.999
# ......Word 'without' has a confidence of 0.995
# ......Word 'any' has a confidence of 0.998
# ......Word 'access' has a confidence of 0.998
# ......Word 'to' has a confidence of 0.999
# ......Word 'an' has a confidence of 0.998
# ......Word 'external' has a confidence of 0.995
# ......Word 'memory,' has a confidence of 0.995
# ......Word 'as' has a confidence of 0.998
# ......Word 'a' has a confidence of 0.996
# ......Word 'parameterized' has a confidence of 0.993
# ......Word 'implicit' has a confidence of 0.996
# ......Word 'knowledge' has a confidence of 0.996
# ......Word 'base' has a confidence of 0.992
# ......Word '[51,' has a confidence of 0.989
# ......Word '52].' has a confidence of 0.989
# ......Word 'While' has a confidence of 0.999
# ......Word 'this' has a confidence of 0.992
# ......Word 'development' has a confidence of 0.995
# ......Word 'is' has a confidence of 0.999
# ......Word 'exciting,' has a confidence of 0.996
# ......Word 'such' has a confidence of 0.992
# ......Word 'models' has a confidence of 0.996
# ......Word 'do' has a confidence of 0.999
# ......Word 'have' has a confidence of 0.987
# ......Word 'down-' has a confidence of 0.995
# ......Word 'sides:' has a confidence of 0.992
# ......Word 'They' has a confidence of 0.991
# ......Word 'cannot' has a confidence of 0.996
# ......Word 'easily' has a confidence of 0.996
# ......Word 'expand' has a confidence of 0.998
# ......Word 'or' has a confidence of 0.992
# ......Word 'revise' has a confidence of 0.993
# ......Word 'their' has a confidence of 0.996
# ......Word 'memory,' has a confidence of 0.995
# ......Word 'can't' has a confidence of 0.995
# ......Word 'straightforwardly' has a confidence of 0.992
# ......Word 'provide' has a confidence of 0.998
# ......Word 'insight' has a confidence of 0.995
# ......Word 'into' has a confidence of 0.989
# ......Word 'their' has a confidence of 0.992
# ......Word 'predictions,' has a confidence of 0.989
# ......Word 'and' has a confidence of 0.996
# ......Word 'may' has a confidence of 0.996
# ......Word 'produce' has a confidence of 0.993
# ......Word '"hallucinations"' has a confidence of 0.903
# ......Word '[38].' has a confidence of 0.947
# ......Word 'Hybrid' has a confidence of 0.995
# ......Word 'models' has a confidence of 0.995
# ......Word 'that' has a confidence of 0.992
# ......Word 'combine' has a confidence of 0.996
# ......Word 'parametric' has a confidence of 0.993
# ......Word 'memory' has a confidence of 0.995
# ......Word 'with' has a confidence of 0.988
# ......Word 'non-parametric' has a confidence of 0.992
# ......Word '(i.e.,' has a confidence of 0.975
# ......Word 'retrieval-based)' has a confidence of 0.986
# ......Word 'memories' has a confidence of 0.994
# ......Word '[20,' has a confidence of 0.979
# ......Word '26,' has a confidence of 0.992
# ......Word '48]' has a confidence of 0.989
# ......Word 'can' has a confidence of 0.998
# ......Word 'address' has a confidence of 0.994
# ......Word 'some' has a confidence of 0.992
# ......Word 'of' has a confidence of 0.997
# ......Word 'these' has a confidence of 0.994
# ......Word 'issues' has a confidence of 0.995
# ......Word 'because' has a confidence of 0.996
# ......Word 'knowledge' has a confidence of 0.995
# ......Word 'can' has a confidence of 0.998
# ......Word 'be' has a confidence of 0.998
# ......Word 'directly' has a confidence of 0.995
# ......Word 'revised' has a confidence of 0.994
# ......Word 'and' has a confidence of 0.999
# ......Word 'expanded,' has a confidence of 0.993
# ......Word 'and' has a confidence of 0.998
# ......Word 'accessed' has a confidence of 0.995
# ......Word 'knowledge' has a confidence of 0.995
# ......Word 'can' has a confidence of 0.998
# ......Word 'be' has a confidence of 0.998
# ......Word 'inspected' has a confidence of 0.992
# ......Word 'and' has a confidence of 0.998
# ......Word 'interpreted.' has a confidence of 0.989
# ......Word 'REALM' has a confidence of 0.995
# ......Word '[20]' has a confidence of 0.904
# ......Word 'and' has a confidence of 0.992
# ......Word 'ORQA' has a confidence of 0.989
# ......Word '[31],' has a confidence of 0.947
# ......Word 'two' has a confidence of 0.998
# ......Word 'recently' has a confidence of 0.994
# ......Word 'introduced' has a confidence of 0.994
# ......Word 'models' has a confidence of 0.996
# ......Word 'that' has a confidence of 0.992
# ......Word 'combine' has a confidence of 0.998
# ......Word 'masked' has a confidence of 0.996
# ......Word 'language' has a confidence of 0.996
# ......Word 'models' has a confidence of 0.998
# ......Word '[8]' has a confidence of 0.845
# ......Word 'with' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.996
# ......Word 'differentiable' has a confidence of 0.994
# ......Word 'retriever,' has a confidence of 0.994
# ......Word 'have' has a confidence of 0.992
# ......Word 'shown' has a confidence of 0.998
# ......Word 'promising' has a confidence of 0.994
# ......Word 'results,' has a confidence of 0.993
# ......Word 'arXiv:2005.11401v4' has a confidence of 0.957
# ......Word '[cs.CL]' has a confidence of 0.833
# ......Word '12' has a confidence of 0.995
# ......Word 'Apr' has a confidence of 0.995
# ......Word '2021' has a confidence of 0.992
# ...Line # 0 has word count 3 and text 'Retrieval-Augmented Generation for' within bounding polygon '[2.3607, 1.3742], [6.1502, 1.3717], [6.1504, 1.6257], [2.3609, 1.6276]'
# ......Word 'Retrieval-Augmented' has a confidence of 0.992
# ......Word 'Generation' has a confidence of 0.995
# ......Word 'for' has a confidence of 0.999
# ......Word 'Knowledge-Intensive' has a confidence of 0.992
# ......Word 'NLP' has a confidence of 0.989
# ......Word 'Tasks' has a confidence of 0.995
# ......Word 'Patrick' has a confidence of 0.995
# ......Word 'Lewis++,' has a confidence of 0.574
# ......Word 'Ethan' has a confidence of 0.997
# ......Word 'Perez*,' has a confidence of 0.962
# ......Word 'Aleksandra' has a confidence of 0.993
# ......Word 'Piktust,' has a confidence of 0.646
# ......Word 'Fabio' has a confidence of 0.997
# ......Word 'Petroni+,' has a confidence of 0.605
# ......Word 'Vladimir' has a confidence of 0.993
# ......Word 'Karpukhint,' has a confidence of 0.681
# ......Word 'Naman' has a confidence of 0.997
# ......Word 'Goyal+,' has a confidence of 0.549
# ......Word 'Heinrich' has a confidence of 0.996
# ......Word 'Küttler*,' has a confidence of 0.595
# ......Word 'Mike' has a confidence of 0.992
# ......Word 'Lewist,' has a confidence of 0.862
# ......Word 'Wen-tau' has a confidence of 0.994
# ......Word 'Yiht,' has a confidence of 0.662
# ......Word 'Tim' has a confidence of 0.998
# ......Word 'Rocktäschel++,' has a confidence of 0.593
# ......Word 'Sebastian' has a confidence of 0.994
# ......Word 'Riedel++,' has a confidence of 0.561
# ......Word 'Douwe' has a confidence of 0.995
# ......Word 'Kielat' has a confidence of 0.791
# ......Word '+Facebook' has a confidence of 0.288
# ......Word 'AI' has a confidence of 0.921
# ......Word 'Research;' has a confidence of 0.999
# ......Word '#University' has a confidence of 0.71
# ......Word 'College' has a confidence of 1.0
# ......Word 'London;' has a confidence of 1.0
# ......Word '*' has a confidence of 1.0
# ......Word 'New' has a confidence of 1.0
# ......Word 'York' has a confidence of 1.0
# ......Word 'University;' has a confidence of 0.999
# ......Word 'plewis@fb.com' has a confidence of 0.99
# ......Word 'Abstract' has a confidence of 0.995
# ......Word 'Large' has a confidence of 0.998
# ......Word 'pre-trained' has a confidence of 0.993
# ......Word 'language' has a confidence of 0.996
# ......Word 'models' has a confidence of 0.999
# ......Word 'have' has a confidence of 0.992
# ......Word 'been' has a confidence of 0.989
# ......Word 'shown' has a confidence of 0.998
# ......Word 'to' has a confidence of 0.999
# ......Word 'store' has a confidence of 0.998
# ......Word 'factual' has a confidence of 0.997
# ......Word 'knowledge' has a confidence of 0.996
# ......Word 'in' has a confidence of 0.998
# ......Word 'their' has a confidence of 0.998
# ......Word 'parameters,' has a confidence of 0.994
# ......Word 'and' has a confidence of 0.999
# ......Word 'achieve' has a confidence of 0.998
# ......Word 'state-of-the-art' has a confidence of 0.993
# ......Word 'results' has a confidence of 0.998
# ......Word 'when' has a confidence of 0.992
# ......Word 'fine-tuned' has a confidence of 0.995
# ......Word 'on' has a confidence of 0.999
# ......Word 'down-' has a confidence of 0.998
# ......Word 'stream' has a confidence of 0.963
# ......Word 'NLP' has a confidence of 0.997
# ......Word 'tasks.' has a confidence of 0.997
# ......Word 'However,' has a confidence of 0.995
# ......Word 'their' has a confidence of 0.997
# ......Word 'ability' has a confidence of 0.998
# ......Word 'to' has a confidence of 0.999
# ......Word 'access' has a confidence of 0.998
# ......Word 'and' has a confidence of 0.996
# ......Word 'precisely' has a confidence of 0.995
# ......Word 'manipulate' has a confidence of 0.996
# ......Word 'knowl-' has a confidence of 0.992
# ......Word 'edge' has a confidence of 0.992
# ......Word 'is' has a confidence of 0.999
# ......Word 'still' has a confidence of 0.998
# ......Word 'limited,' has a confidence of 0.994
# ......Word 'and' has a confidence of 0.999
# ......Word 'hence' has a confidence of 0.998
# ......Word 'on' has a confidence of 0.999
# ......Word 'knowledge-intensive' has a confidence of 0.993
# ......Word 'tasks,' has a confidence of 0.996
# ......Word 'their' has a confidence of 0.998
# ......Word 'performance' has a confidence of 0.993
# ......Word 'lags' has a confidence of 0.992
# ......Word 'behind' has a confidence of 0.995
# ......Word 'task-specific' has a confidence of 0.992
# ......Word 'architectures.' has a confidence of 0.992
# ......Word 'Additionally,' has a confidence of 0.992
# ......Word 'providing' has a confidence of 0.995
# ......Word 'provenance' has a confidence of 0.995
# ......Word 'for' has a confidence of 0.999
# ......Word 'their' has a confidence of 0.996
# ......Word 'decisions' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'updating' has a confidence of 0.997
# ......Word 'their' has a confidence of 0.998
# ......Word 'world' has a confidence of 0.998
# ......Word 'knowledge' has a confidence of 0.996
# ......Word 'remain' has a confidence of 0.998
# ......Word 'open' has a confidence of 0.992
# ......Word 'research' has a confidence of 0.995
# ......Word 'problems.' has a confidence of 0.995
# ......Word 'Pre-' has a confidence of 0.988
# ......Word 'trained' has a confidence of 0.995
# ......Word 'models' has a confidence of 0.995
# ......Word 'with' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.995
# ......Word 'differentiable' has a confidence of 0.994
# ......Word 'access' has a confidence of 0.997
# ......Word 'mechanism' has a confidence of 0.996
# ......Word 'to' has a confidence of 0.999
# ......Word 'explicit' has a confidence of 0.993
# ......Word 'non-parametric' has a confidence of 0.993
# ......Word 'memory' has a confidence of 0.998
# ......Word 'have' has a confidence of 0.992
# ......Word 'so' has a confidence of 0.998
# ......Word 'far' has a confidence of 0.998
# ......Word 'been' has a confidence of 0.989
# ......Word 'only' has a confidence of 0.992
# ......Word 'investigated' has a confidence of 0.995
# ......Word 'for' has a confidence of 0.999
# ......Word 'extractive' has a confidence of 0.995
# ......Word 'downstream' has a confidence of 0.995
# ......Word 'tasks.' has a confidence of 0.995
# ......Word 'We' has a confidence of 0.998
# ......Word 'explore' has a confidence of 0.996
# ......Word 'a' has a confidence of 0.995
# ......Word 'general-purpose' has a confidence of 0.992
# ......Word 'fine-tuning' has a confidence of 0.992
# ......Word 'recipe' has a confidence of 0.998
# ......Word 'for' has a confidence of 0.999
# ......Word 'retrieval-augmented' has a confidence of 0.992
# ......Word 'generation' has a confidence of 0.995
# ......Word '(RAG)' has a confidence of 0.996
# ......Word '-' has a confidence of 0.992
# ......Word 'models' has a confidence of 0.998
# ......Word 'which' has a confidence of 0.999
# ......Word 'combine' has a confidence of 0.997
# ......Word 'pre-trained' has a confidence of 0.995
# ......Word 'parametric' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'non-parametric' has a confidence of 0.992
# ......Word 'mem-' has a confidence of 0.992
# ......Word 'ory' has a confidence of 0.992
# ......Word 'for' has a confidence of 0.995
# ......Word 'language' has a confidence of 0.995
# ......Word 'generation.' has a confidence of 0.992
# ......Word 'We' has a confidence of 0.998
# ......Word 'introduce' has a confidence of 0.993
# ......Word 'RAG' has a confidence of 0.997
# ......Word 'models' has a confidence of 0.996
# ......Word 'where' has a confidence of 0.994
# ......Word 'the' has a confidence of 0.999
# ......Word 'parametric' has a confidence of 0.993
# ......Word 'memory' has a confidence of 0.995
# ......Word 'is' has a confidence of 0.987
# ......Word 'a' has a confidence of 0.994
# ......Word 'pre-trained' has a confidence of 0.992
# ......Word 'seq2seq' has a confidence of 0.992
# ......Word 'model' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'the' has a confidence of 0.999
# ......Word 'non-parametric' has a confidence of 0.992
# ......Word 'memory' has a confidence of 0.998
# ......Word 'is' has a confidence of 0.998
# ......Word 'a' has a confidence of 0.995
# ......Word 'dense' has a confidence of 0.997
# ......Word 'vector' has a confidence of 0.995
# ......Word 'index' has a confidence of 0.994
# ......Word 'of' has a confidence of 0.998
# ......Word 'Wikipedia,' has a confidence of 0.993
# ......Word 'accessed' has a confidence of 0.996
# ......Word 'with' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.995
# ......Word 'pre-trained' has a confidence of 0.993
# ......Word 'neural' has a confidence of 0.994
# ......Word 'retriever.' has a confidence of 0.992
# ......Word 'We' has a confidence of 0.999
# ......Word 'com-' has a confidence of 0.992
# ......Word 'pare' has a confidence of 0.989
# ......Word 'two' has a confidence of 0.998
# ......Word 'RAG' has a confidence of 0.998
# ......Word 'formulations,' has a confidence of 0.992
# ......Word 'one' has a confidence of 0.999
# ......Word 'which' has a confidence of 0.999
# ......Word 'conditions' has a confidence of 0.995
# ......Word 'on' has a confidence of 0.999
# ......Word 'the' has a confidence of 0.992
# ......Word 'same' has a confidence of 0.992
# ......Word 'retrieved' has a confidence of 0.994
# ......Word 'passages' has a confidence of 0.994
# ......Word 'across' has a confidence of 0.997
# ......Word 'the' has a confidence of 0.999
# ......Word 'whole' has a confidence of 0.997
# ......Word 'generated' has a confidence of 0.995
# ......Word 'sequence,' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'another' has a confidence of 0.998
# ......Word 'which' has a confidence of 0.998
# ......Word 'can' has a confidence of 0.998
# ......Word 'use' has a confidence of 0.998
# ......Word 'different' has a confidence of 0.994
# ......Word 'passages' has a confidence of 0.995
# ......Word 'per' has a confidence of 0.997
# ......Word 'token.' has a confidence of 0.998
# ......Word 'We' has a confidence of 0.989
# ......Word 'fine-tune' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'evaluate' has a confidence of 0.997
# ......Word 'our' has a confidence of 0.998
# ......Word 'models' has a confidence of 0.997
# ......Word 'on' has a confidence of 0.999
# ......Word 'a' has a confidence of 0.996
# ......Word 'wide' has a confidence of 0.992
# ......Word 'range' has a confidence of 0.998
# ......Word 'of' has a confidence of 0.998
# ......Word 'knowledge-' has a confidence of 0.995
# ......Word 'intensive' has a confidence of 0.994
# ......Word 'NLP' has a confidence of 0.995
# ......Word 'tasks' has a confidence of 0.996
# ......Word 'and' has a confidence of 0.998
# ......Word 'set' has a confidence of 0.997
# ......Word 'the' has a confidence of 0.999
# ......Word 'state' has a confidence of 0.997
# ......Word 'of' has a confidence of 0.992
# ......Word 'the' has a confidence of 0.999
# ......Word 'art' has a confidence of 0.998
# ......Word 'on' has a confidence of 0.999
# ......Word 'three' has a confidence of 0.996
# ......Word 'open' has a confidence of 0.989
# ......Word 'domain' has a confidence of 0.994
# ......Word 'QA' has a confidence of 0.992
# ......Word 'tasks,' has a confidence of 0.992
# ......Word 'outperforming' has a confidence of 0.993
# ......Word 'parametric' has a confidence of 0.992
# ......Word 'seq2seq' has a confidence of 0.987
# ......Word 'models' has a confidence of 0.994
# ......Word 'and' has a confidence of 0.998
# ......Word 'task-specific' has a confidence of 0.992
# ......Word 'retrieve-and-extract' has a confidence of 0.992
# ......Word 'architectures.' has a confidence of 0.992
# ......Word 'For' has a confidence of 0.998
# ......Word 'language' has a confidence of 0.994
# ......Word 'generation' has a confidence of 0.995
# ......Word 'tasks,' has a confidence of 0.993
# ......Word 'we' has a confidence of 0.998
# ......Word 'find' has a confidence of 0.992
# ......Word 'that' has a confidence of 0.988
# ......Word 'RAG' has a confidence of 0.997
# ......Word 'models' has a confidence of 0.997
# ......Word 'generate' has a confidence of 0.994
# ......Word 'more' has a confidence of 0.992
# ......Word 'specific,' has a confidence of 0.992
# ......Word 'diverse' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.995
# ......Word 'factual' has a confidence of 0.994
# ......Word 'language' has a confidence of 0.996
# ......Word 'than' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.995
# ......Word 'state-of-the-art' has a confidence of 0.992
# ......Word 'parametric-only' has a confidence of 0.993
# ......Word 'seq2seq' has a confidence of 0.977
# ......Word 'baseline.' has a confidence of 0.996
# ......Word '1' has a confidence of 0.997
# ......Word 'Introduction' has a confidence of 0.993
# ......Word 'Pre-trained' has a confidence of 0.995
# ......Word 'neural' has a confidence of 0.998
# ......Word 'language' has a confidence of 0.998
# ......Word 'models' has a confidence of 0.998
# ......Word 'have' has a confidence of 0.992
# ......Word 'been' has a confidence of 0.992
# ......Word 'shown' has a confidence of 0.998
# ......Word 'to' has a confidence of 0.999
# ......Word 'learn' has a confidence of 0.998
# ......Word 'a' has a confidence of 0.996
# ......Word 'substantial' has a confidence of 0.995
# ......Word 'amount' has a confidence of 0.999
# ......Word 'of' has a confidence of 0.992
# ......Word 'in-depth' has a confidence of 0.997
# ......Word 'knowl-' has a confidence of 0.993
# ......Word 'edge' has a confidence of 0.992
# ......Word 'from' has a confidence of 0.992
# ......Word 'data' has a confidence of 0.992
# ......Word '[47].' has a confidence of 0.975
# ......Word 'They' has a confidence of 0.992
# ......Word 'can' has a confidence of 0.999
# ......Word 'do' has a confidence of 0.999
# ......Word 'so' has a confidence of 0.999
# ......Word 'without' has a confidence of 0.995
# ......Word 'any' has a confidence of 0.998
# ......Word 'access' has a confidence of 0.998
# ......Word 'to' has a confidence of 0.999
# ......Word 'an' has a confidence of 0.998
# ......Word 'external' has a confidence of 0.995
# ......Word 'memory,' has a confidence of 0.995
# ......Word 'as' has a confidence of 0.998
# ......Word 'a' has a confidence of 0.996
# ......Word 'parameterized' has a confidence of 0.993
# ......Word 'implicit' has a confidence of 0.996
# ......Word 'knowledge' has a confidence of 0.996
# ......Word 'base' has a confidence of 0.992
# ......Word '[51,' has a confidence of 0.989
# ......Word '52].' has a confidence of 0.989
# ......Word 'While' has a confidence of 0.999
# ......Word 'this' has a confidence of 0.992
# ......Word 'development' has a confidence of 0.995
# ......Word 'is' has a confidence of 0.999
# ......Word 'exciting,' has a confidence of 0.996
# ......Word 'such' has a confidence of 0.992
# ......Word 'models' has a confidence of 0.996
# ......Word 'do' has a confidence of 0.999
# ......Word 'have' has a confidence of 0.987
# ......Word 'down-' has a confidence of 0.995
# ......Word 'sides:' has a confidence of 0.992
# ......Word 'They' has a confidence of 0.991
# ......Word 'cannot' has a confidence of 0.996
# ......Word 'easily' has a confidence of 0.996
# ......Word 'expand' has a confidence of 0.998
# ......Word 'or' has a confidence of 0.992
# ......Word 'revise' has a confidence of 0.993
# ......Word 'their' has a confidence of 0.996
# ......Word 'memory,' has a confidence of 0.995
# ......Word 'can't' has a confidence of 0.995
# ......Word 'straightforwardly' has a confidence of 0.992
# ......Word 'provide' has a confidence of 0.998
# ......Word 'insight' has a confidence of 0.995
# ......Word 'into' has a confidence of 0.989
# ......Word 'their' has a confidence of 0.992
# ......Word 'predictions,' has a confidence of 0.989
# ......Word 'and' has a confidence of 0.996
# ......Word 'may' has a confidence of 0.996
# ......Word 'produce' has a confidence of 0.993
# ......Word '"hallucinations"' has a confidence of 0.903
# ......Word '[38].' has a confidence of 0.947
# ......Word 'Hybrid' has a confidence of 0.995
# ......Word 'models' has a confidence of 0.995
# ......Word 'that' has a confidence of 0.992
# ......Word 'combine' has a confidence of 0.996
# ......Word 'parametric' has a confidence of 0.993
# ......Word 'memory' has a confidence of 0.995
# ......Word 'with' has a confidence of 0.988
# ......Word 'non-parametric' has a confidence of 0.992
# ......Word '(i.e.,' has a confidence of 0.975
# ......Word 'retrieval-based)' has a confidence of 0.986
# ......Word 'memories' has a confidence of 0.994
# ......Word '[20,' has a confidence of 0.979
# ......Word '26,' has a confidence of 0.992
# ......Word '48]' has a confidence of 0.989
# ......Word 'can' has a confidence of 0.998
# ......Word 'address' has a confidence of 0.994
# ......Word 'some' has a confidence of 0.992
# ......Word 'of' has a confidence of 0.997
# ......Word 'these' has a confidence of 0.994
# ......Word 'issues' has a confidence of 0.995
# ......Word 'because' has a confidence of 0.996
# ......Word 'knowledge' has a confidence of 0.995
# ......Word 'can' has a confidence of 0.998
# ......Word 'be' has a confidence of 0.998
# ......Word 'directly' has a confidence of 0.995
# ......Word 'revised' has a confidence of 0.994
# ......Word 'and' has a confidence of 0.999
# ......Word 'expanded,' has a confidence of 0.993
# ......Word 'and' has a confidence of 0.998
# ......Word 'accessed' has a confidence of 0.995
# ......Word 'knowledge' has a confidence of 0.995
# ......Word 'can' has a confidence of 0.998
# ......Word 'be' has a confidence of 0.998
# ......Word 'inspected' has a confidence of 0.992
# ......Word 'and' has a confidence of 0.998
# ......Word 'interpreted.' has a confidence of 0.989
# ......Word 'REALM' has a confidence of 0.995
# ......Word '[20]' has a confidence of 0.904
# ......Word 'and' has a confidence of 0.992
# ......Word 'ORQA' has a confidence of 0.989
# ......Word '[31],' has a confidence of 0.947
# ......Word 'two' has a confidence of 0.998
# ......Word 'recently' has a confidence of 0.994
# ......Word 'introduced' has a confidence of 0.994
# ......Word 'models' has a confidence of 0.996
# ......Word 'that' has a confidence of 0.992
# ......Word 'combine' has a confidence of 0.998
# ......Word 'masked' has a confidence of 0.996
# ......Word 'language' has a confidence of 0.996
# ......Word 'models' has a confidence of 0.998
# ......Word '[8]' has a confidence of 0.845
# ......Word 'with' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.996
# ......Word 'differentiable' has a confidence of 0.994
# ......Word 'retriever,' has a confidence of 0.994
# ......Word 'have' has a confidence of 0.992
# ......Word 'shown' has a confidence of 0.998
# ......Word 'promising' has a confidence of 0.994
# ......Word 'results,' has a confidence of 0.993
# ......Word 'arXiv:2005.11401v4' has a confidence of 0.957
# ......Word '[cs.CL]' has a confidence of 0.833
# ......Word '12' has a confidence of 0.995
# ......Word 'Apr' has a confidence of 0.995
# ......Word '2021' has a confidence of 0.992
# ...Line # 1 has word count 3 and text 'Knowledge-Intensive NLP Tasks' within bounding polygon '[2.5797, 1.6538], [5.9248, 1.6509], [5.925, 1.8989], [2.5799, 1.9018]'
# ......Word 'Retrieval-Augmented' has a confidence of 0.992
# ......Word 'Generation' has a confidence of 0.995
# ......Word 'for' has a confidence of 0.999
# ......Word 'Knowledge-Intensive' has a confidence of 0.992
# ......Word 'NLP' has a confidence of 0.989
# ......Word 'Tasks' has a confidence of 0.995
# ......Word 'Patrick' has a confidence of 0.995
# ......Word 'Lewis++,' has a confidence of 0.574
# ......Word 'Ethan' has a confidence of 0.997
# ......Word 'Perez*,' has a confidence of 0.962
# ......Word 'Aleksandra' has a confidence of 0.993
# ......Word 'Piktust,' has a confidence of 0.646
# ......Word 'Fabio' has a confidence of 0.997
# ......Word 'Petroni+,' has a confidence of 0.605
# ......Word 'Vladimir' has a confidence of 0.993
# ......Word 'Karpukhint,' has a confidence of 0.681
# ......Word 'Naman' has a confidence of 0.997
# ......Word 'Goyal+,' has a confidence of 0.549
# ......Word 'Heinrich' has a confidence of 0.996
# ......Word 'Küttler*,' has a confidence of 0.595
# ......Word 'Mike' has a confidence of 0.992
# ......Word 'Lewist,' has a confidence of 0.862
# ......Word 'Wen-tau' has a confidence of 0.994
# ......Word 'Yiht,' has a confidence of 0.662
# ......Word 'Tim' has a confidence of 0.998
# ......Word 'Rocktäschel++,' has a confidence of 0.593
# ......Word 'Sebastian' has a confidence of 0.994
# ......Word 'Riedel++,' has a confidence of 0.561
# ......Word 'Douwe' has a confidence of 0.995
# ......Word 'Kielat' has a confidence of 0.791
# ......Word '+Facebook' has a confidence of 0.288
# ......Word 'AI' has a confidence of 0.921
# ......Word 'Research;' has a confidence of 0.999
# ......Word '#University' has a confidence of 0.71
# ......Word 'College' has a confidence of 1.0
# ......Word 'London;' has a confidence of 1.0
# ......Word '*' has a confidence of 1.0
# ......Word 'New' has a confidence of 1.0
# ......Word 'York' has a confidence of 1.0
# ......Word 'University;' has a confidence of 0.999
# ......Word 'plewis@fb.com' has a confidence of 0.99
# ......Word 'Abstract' has a confidence of 0.995
# ......Word 'Large' has a confidence of 0.998
# ......Word 'pre-trained' has a confidence of 0.993
# ......Word 'language' has a confidence of 0.996
# ......Word 'models' has a confidence of 0.999
# ......Word 'have' has a confidence of 0.992
# ......Word 'been' has a confidence of 0.989
# ......Word 'shown' has a confidence of 0.998
# ......Word 'to' has a confidence of 0.999
# ......Word 'store' has a confidence of 0.998
# ......Word 'factual' has a confidence of 0.997
# ......Word 'knowledge' has a confidence of 0.996
# ......Word 'in' has a confidence of 0.998
# ......Word 'their' has a confidence of 0.998
# ......Word 'parameters,' has a confidence of 0.994
# ......Word 'and' has a confidence of 0.999
# ......Word 'achieve' has a confidence of 0.998
# ......Word 'state-of-the-art' has a confidence of 0.993
# ......Word 'results' has a confidence of 0.998
# ......Word 'when' has a confidence of 0.992
# ......Word 'fine-tuned' has a confidence of 0.995
# ......Word 'on' has a confidence of 0.999
# ......Word 'down-' has a confidence of 0.998
# ......Word 'stream' has a confidence of 0.963
# ......Word 'NLP' has a confidence of 0.997
# ......Word 'tasks.' has a confidence of 0.997
# ......Word 'However,' has a confidence of 0.995
# ......Word 'their' has a confidence of 0.997
# ......Word 'ability' has a confidence of 0.998
# ......Word 'to' has a confidence of 0.999
# ......Word 'access' has a confidence of 0.998
# ......Word 'and' has a confidence of 0.996
# ......Word 'precisely' has a confidence of 0.995
# ......Word 'manipulate' has a confidence of 0.996
# ......Word 'knowl-' has a confidence of 0.992
# ......Word 'edge' has a confidence of 0.992
# ......Word 'is' has a confidence of 0.999
# ......Word 'still' has a confidence of 0.998
# ......Word 'limited,' has a confidence of 0.994
# ......Word 'and' has a confidence of 0.999
# ......Word 'hence' has a confidence of 0.998
# ......Word 'on' has a confidence of 0.999
# ......Word 'knowledge-intensive' has a confidence of 0.993
# ......Word 'tasks,' has a confidence of 0.996
# ......Word 'their' has a confidence of 0.998
# ......Word 'performance' has a confidence of 0.993
# ......Word 'lags' has a confidence of 0.992
# ......Word 'behind' has a confidence of 0.995
# ......Word 'task-specific' has a confidence of 0.992
# ......Word 'architectures.' has a confidence of 0.992
# ......Word 'Additionally,' has a confidence of 0.992
# ......Word 'providing' has a confidence of 0.995
# ......Word 'provenance' has a confidence of 0.995
# ......Word 'for' has a confidence of 0.999
# ......Word 'their' has a confidence of 0.996
# ......Word 'decisions' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'updating' has a confidence of 0.997
# ......Word 'their' has a confidence of 0.998
# ......Word 'world' has a confidence of 0.998
# ......Word 'knowledge' has a confidence of 0.996
# ......Word 'remain' has a confidence of 0.998
# ......Word 'open' has a confidence of 0.992
# ......Word 'research' has a confidence of 0.995
# ......Word 'problems.' has a confidence of 0.995
# ......Word 'Pre-' has a confidence of 0.988
# ......Word 'trained' has a confidence of 0.995
# ......Word 'models' has a confidence of 0.995
# ......Word 'with' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.995
# ......Word 'differentiable' has a confidence of 0.994
# ......Word 'access' has a confidence of 0.997
# ......Word 'mechanism' has a confidence of 0.996
# ......Word 'to' has a confidence of 0.999
# ......Word 'explicit' has a confidence of 0.993
# ......Word 'non-parametric' has a confidence of 0.993
# ......Word 'memory' has a confidence of 0.998
# ......Word 'have' has a confidence of 0.992
# ......Word 'so' has a confidence of 0.998
# ......Word 'far' has a confidence of 0.998
# ......Word 'been' has a confidence of 0.989
# ......Word 'only' has a confidence of 0.992
# ......Word 'investigated' has a confidence of 0.995
# ......Word 'for' has a confidence of 0.999
# ......Word 'extractive' has a confidence of 0.995
# ......Word 'downstream' has a confidence of 0.995
# ......Word 'tasks.' has a confidence of 0.995
# ......Word 'We' has a confidence of 0.998
# ......Word 'explore' has a confidence of 0.996
# ......Word 'a' has a confidence of 0.995
# ......Word 'general-purpose' has a confidence of 0.992
# ......Word 'fine-tuning' has a confidence of 0.992
# ......Word 'recipe' has a confidence of 0.998
# ......Word 'for' has a confidence of 0.999
# ......Word 'retrieval-augmented' has a confidence of 0.992
# ......Word 'generation' has a confidence of 0.995
# ......Word '(RAG)' has a confidence of 0.996
# ......Word '-' has a confidence of 0.992
# ......Word 'models' has a confidence of 0.998
# ......Word 'which' has a confidence of 0.999
# ......Word 'combine' has a confidence of 0.997
# ......Word 'pre-trained' has a confidence of 0.995
# ......Word 'parametric' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'non-parametric' has a confidence of 0.992
# ......Word 'mem-' has a confidence of 0.992
# ......Word 'ory' has a confidence of 0.992
# ......Word 'for' has a confidence of 0.995
# ......Word 'language' has a confidence of 0.995
# ......Word 'generation.' has a confidence of 0.992
# ......Word 'We' has a confidence of 0.998
# ......Word 'introduce' has a confidence of 0.993
# ......Word 'RAG' has a confidence of 0.997
# ......Word 'models' has a confidence of 0.996
# ......Word 'where' has a confidence of 0.994
# ......Word 'the' has a confidence of 0.999
# ......Word 'parametric' has a confidence of 0.993
# ......Word 'memory' has a confidence of 0.995
# ......Word 'is' has a confidence of 0.987
# ......Word 'a' has a confidence of 0.994
# ......Word 'pre-trained' has a confidence of 0.992
# ......Word 'seq2seq' has a confidence of 0.992
# ......Word 'model' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'the' has a confidence of 0.999
# ......Word 'non-parametric' has a confidence of 0.992
# ......Word 'memory' has a confidence of 0.998
# ......Word 'is' has a confidence of 0.998
# ......Word 'a' has a confidence of 0.995
# ......Word 'dense' has a confidence of 0.997
# ......Word 'vector' has a confidence of 0.995
# ......Word 'index' has a confidence of 0.994
# ......Word 'of' has a confidence of 0.998
# ......Word 'Wikipedia,' has a confidence of 0.993
# ......Word 'accessed' has a confidence of 0.996
# ......Word 'with' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.995
# ......Word 'pre-trained' has a confidence of 0.993
# ......Word 'neural' has a confidence of 0.994
# ......Word 'retriever.' has a confidence of 0.992
# ......Word 'We' has a confidence of 0.999
# ......Word 'com-' has a confidence of 0.992
# ......Word 'pare' has a confidence of 0.989
# ......Word 'two' has a confidence of 0.998
# ......Word 'RAG' has a confidence of 0.998
# ......Word 'formulations,' has a confidence of 0.992
# ......Word 'one' has a confidence of 0.999
# ......Word 'which' has a confidence of 0.999
# ......Word 'conditions' has a confidence of 0.995
# ......Word 'on' has a confidence of 0.999
# ......Word 'the' has a confidence of 0.992
# ......Word 'same' has a confidence of 0.992
# ......Word 'retrieved' has a confidence of 0.994
# ......Word 'passages' has a confidence of 0.994
# ......Word 'across' has a confidence of 0.997
# ......Word 'the' has a confidence of 0.999
# ......Word 'whole' has a confidence of 0.997
# ......Word 'generated' has a confidence of 0.995
# ......Word 'sequence,' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'another' has a confidence of 0.998
# ......Word 'which' has a confidence of 0.998
# ......Word 'can' has a confidence of 0.998
# ......Word 'use' has a confidence of 0.998
# ......Word 'different' has a confidence of 0.994
# ......Word 'passages' has a confidence of 0.995
# ......Word 'per' has a confidence of 0.997
# ......Word 'token.' has a confidence of 0.998
# ......Word 'We' has a confidence of 0.989
# ......Word 'fine-tune' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'evaluate' has a confidence of 0.997
# ......Word 'our' has a confidence of 0.998
# ......Word 'models' has a confidence of 0.997
# ......Word 'on' has a confidence of 0.999
# ......Word 'a' has a confidence of 0.996
# ......Word 'wide' has a confidence of 0.992
# ......Word 'range' has a confidence of 0.998
# ......Word 'of' has a confidence of 0.998
# ......Word 'knowledge-' has a confidence of 0.995
# ......Word 'intensive' has a confidence of 0.994
# ......Word 'NLP' has a confidence of 0.995
# ...
# ......Word 'across' has a confidence of 0.997
# ......Word 'the' has a confidence of 0.999
# ......Word 'whole' has a confidence of 0.997
# ......Word 'generated' has a confidence of 0.995
# ......Word 'sequence,' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'another' has a confidence of 0.998
# ......Word 'which' has a confidence of 0.998
# ......Word 'can' has a confidence of 0.998
# ......Word 'use' has a confidence of 0.998
# ......Word 'different' has a confidence of 0.994
# ......Word 'passages' has a confidence of 0.995
# ......Word 'per' has a confidence of 0.997
# ......Word 'token.' has a confidence of 0.998
# ......Word 'We' has a confidence of 0.989
# ......Word 'fine-tune' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.999
# ......Word 'evaluate' has a confidence of 0.997
# ......Word 'our' has a confidence of 0.998
# ......Word 'models' has a confidence of 0.997
# ......Word 'on' has a confidence of 0.999
# ......Word 'a' has a confidence of 0.996
# ......Word 'wide' has a confidence of 0.992
# ......Word 'range' has a confidence of 0.998
# ......Word 'of' has a confidence of 0.998
# ......Word 'knowledge-' has a confidence of 0.995
# ......Word 'intensive' has a confidence of 0.994
# ......Word 'NLP' has a confidence of 0.995
# ......Word 'tasks' has a confidence of 0.996
# ......Word 'and' has a confidence of 0.998
# ......Word 'set' has a confidence of 0.997
# ......Word 'the' has a confidence of 0.999
# ......Word 'state' has a confidence of 0.997
# ......Word 'of' has a confidence of 0.992
# ......Word 'the' has a confidence of 0.999
# ......Word 'art' has a confidence of 0.998
# ......Word 'on' has a confidence of 0.999
# ......Word 'three' has a confidence of 0.996
# ......Word 'open' has a confidence of 0.989
# ......Word 'domain' has a confidence of 0.994
# ......Word 'QA' has a confidence of 0.992
# ......Word 'tasks,' has a confidence of 0.992
# ......Word 'outperforming' has a confidence of 0.993
# ......Word 'parametric' has a confidence of 0.992
# ......Word 'seq2seq' has a confidence of 0.987
# ......Word 'models' has a confidence of 0.994
# ......Word 'and' has a confidence of 0.998
# ......Word 'task-specific' has a confidence of 0.992
# ......Word 'retrieve-and-extract' has a confidence of 0.992
# ......Word 'architectures.' has a confidence of 0.992
# ......Word 'For' has a confidence of 0.998
# ......Word 'language' has a confidence of 0.994
# ......Word 'generation' has a confidence of 0.995
# ......Word 'tasks,' has a confidence of 0.993
# ......Word 'we' has a confidence of 0.998
# ......Word 'find' has a confidence of 0.992
# ......Word 'that' has a confidence of 0.988
# ......Word 'RAG' has a confidence of 0.997
# ......Word 'models' has a confidence of 0.997
# ......Word 'generate' has a confidence of 0.994
# ......Word 'more' has a confidence of 0.992
# ......Word 'specific,' has a confidence of 0.992
# ......Word 'diverse' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.995
# ......Word 'factual' has a confidence of 0.994
# ......Word 'language' has a confidence of 0.996
# ......Word 'than' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.995
# ......Word 'state-of-the-art' has a confidence of 0.992
# ......Word 'parametric-only' has a confidence of 0.993
# ......Word 'seq2seq' has a confidence of 0.977
# ......Word 'baseline.' has a confidence of 0.996
# ......Word '1' has a confidence of 0.997
# ......Word 'Introduction' has a confidence of 0.993
# ......Word 'Pre-trained' has a confidence of 0.995
# ......Word 'neural' has a confidence of 0.998
# ......Word 'language' has a confidence of 0.998
# ......Word 'models' has a confidence of 0.998
# ......Word 'have' has a confidence of 0.992
# ......Word 'been' has a confidence of 0.992
# ......Word 'shown' has a confidence of 0.998
# ......Word 'to' has a confidence of 0.999
# ......Word 'learn' has a confidence of 0.998
# ......Word 'a' has a confidence of 0.996
# ......Word 'substantial' has a confidence of 0.995
# ......Word 'amount' has a confidence of 0.999
# ......Word 'of' has a confidence of 0.992
# ......Word 'in-depth' has a confidence of 0.997
# ......Word 'knowl-' has a confidence of 0.993
# ......Word 'edge' has a confidence of 0.992
# ......Word 'from' has a confidence of 0.992
# ......Word 'data' has a confidence of 0.992
# ......Word '[47].' has a confidence of 0.975
# ......Word 'They' has a confidence of 0.992
# ......Word 'can' has a confidence of 0.999
# ......Word 'do' has a confidence of 0.999
# ......Word 'so' has a confidence of 0.999
# ......Word 'without' has a confidence of 0.995
# ......Word 'any' has a confidence of 0.998
# ......Word 'access' has a confidence of 0.998
# ......Word 'to' has a confidence of 0.999
# ......Word 'an' has a confidence of 0.998
# ......Word 'external' has a confidence of 0.995
# ......Word 'memory,' has a confidence of 0.995
# ......Word 'as' has a confidence of 0.998
# ......Word 'a' has a confidence of 0.996
# ......Word 'parameterized' has a confidence of 0.993
# ......Word 'implicit' has a confidence of 0.996
# ......Word 'knowledge' has a confidence of 0.996
# ......Word 'base' has a confidence of 0.992
# ......Word '[51,' has a confidence of 0.989
# ......Word '52].' has a confidence of 0.989
# ......Word 'While' has a confidence of 0.999
# ......Word 'this' has a confidence of 0.992
# ......Word 'development' has a confidence of 0.995
# ......Word 'is' has a confidence of 0.999
# ......Word 'exciting,' has a confidence of 0.996
# ......Word 'such' has a confidence of 0.992
# ......Word 'models' has a confidence of 0.996
# ......Word 'do' has a confidence of 0.999
# ......Word 'have' has a confidence of 0.987
# ......Word 'down-' has a confidence of 0.995
# ......Word 'sides:' has a confidence of 0.992
# ......Word 'They' has a confidence of 0.991
# ......Word 'cannot' has a confidence of 0.996
# ......Word 'easily' has a confidence of 0.996
# ......Word 'expand' has a confidence of 0.998
# ......Word 'or' has a confidence of 0.992
# ......Word 'revise' has a confidence of 0.993
# ......Word 'their' has a confidence of 0.996
# ......Word 'memory,' has a confidence of 0.995
# ......Word 'can't' has a confidence of 0.995
# ......Word 'straightforwardly' has a confidence of 0.992
# ......Word 'provide' has a confidence of 0.998
# ......Word 'insight' has a confidence of 0.995
# ......Word 'into' has a confidence of 0.989
# ......Word 'their' has a confidence of 0.992
# ......Word 'predictions,' has a confidence of 0.989
# ......Word 'and' has a confidence of 0.996
# ......Word 'may' has a confidence of 0.996
# ......Word 'produce' has a confidence of 0.993
# ......Word '"hallucinations"' has a confidence of 0.903
# ......Word '[38].' has a confidence of 0.947
# ......Word 'Hybrid' has a confidence of 0.995
# ......Word 'models' has a confidence of 0.995
# ......Word 'that' has a confidence of 0.992
# ......Word 'combine' has a confidence of 0.996
# ......Word 'parametric' has a confidence of 0.993
# ......Word 'memory' has a confidence of 0.995
# ......Word 'with' has a confidence of 0.988
# ......Word 'non-parametric' has a confidence of 0.992
# ......Word '(i.e.,' has a confidence of 0.975
# ......Word 'retrieval-based)' has a confidence of 0.986
# ......Word 'memories' has a confidence of 0.994
# ......Word '[20,' has a confidence of 0.979
# ......Word '26,' has a confidence of 0.992
# ......Word '48]' has a confidence of 0.989
# ......Word 'can' has a confidence of 0.998
# ......Word 'address' has a confidence of 0.994
# ......Word 'some' has a confidence of 0.992
# ......Word 'of' has a confidence of 0.997
# ......Word 'these' has a confidence of 0.994
# ......Word 'issues' has a confidence of 0.995
# ......Word 'because' has a confidence of 0.996
# ......Word 'knowledge' has a confidence of 0.995
# ......Word 'can' has a confidence of 0.998
# ......Word 'be' has a confidence of 0.998
# ......Word 'directly' has a confidence of 0.995
# ......Word 'revised' has a confidence of 0.994
# ......Word 'and' has a confidence of 0.999
# ......Word 'expanded,' has a confidence of 0.993
# ......Word 'and' has a confidence of 0.998
# ......Word 'accessed' has a confidence of 0.995
# ......Word 'knowledge' has a confidence of 0.995
# ......Word 'can' has a confidence of 0.998
# ......Word 'be' has a confidence of 0.998
# ......Word 'inspected' has a confidence of 0.992
# ......Word 'and' has a confidence of 0.998
# ......Word 'interpreted.' has a confidence of 0.989
# ......Word 'REALM' has a confidence of 0.995
# ......Word '[20]' has a confidence of 0.904
# ......Word 'and' has a confidence of 0.992
# ......Word 'ORQA' has a confidence of 0.989
# ......Word '[31],' has a confidence of 0.947
# ......Word 'two' has a confidence of 0.998
# ......Word 'recently' has a confidence of 0.994
# ......Word 'introduced' has a confidence of 0.994
# ......Word 'models' has a confidence of 0.996
# ......Word 'that' has a confidence of 0.992
# ......Word 'combine' has a confidence of 0.998
# ......Word 'masked' has a confidence of 0.996
# ......Word 'language' has a confidence of 0.996
# ......Word 'models' has a confidence of 0.998
# ......Word '[8]' has a confidence of 0.845
# ......Word 'with' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.996
# ......Word 'differentiable' has a confidence of 0.994
# ......Word 'retriever,' has a confidence of 0.994
# ......Word 'have' has a confidence of 0.992
# ......Word 'shown' has a confidence of 0.998
# ......Word 'promising' has a confidence of 0.994
# ......Word 'results,' has a confidence of 0.993
# ......Word 'arXiv:2005.11401v4' has a confidence of 0.957
# ......Word '[cs.CL]' has a confidence of 0.833
# ......Word '12' has a confidence of 0.995
# ......Word 'Apr' has a confidence of 0.995
# ......Word '2021' has a confidence of 0.992
# ...Line # 40 has word count 5 and text 'arXiv:2005.11401v4 [cs.CL] 12 Apr 2021' within bounding polygon '[0.2283, 7.7851], [0.2237, 2.9535], [0.4922, 2.9532], [0.4968, 7.7849]'
# Selection mark is 'unselected' within bounding polygon '[0.2499, 5.896], [0.4561, 5.896], [0.4561, 6.0261], [0.2499, 6.0261]' and has a confidence of 0.1
# Selection mark is 'unselected' within bounding polygon '[0.2477, 6.8001], [0.4555, 6.8001], [0.4555, 6.928], [0.2477, 6.928]' and has a confidence of 0.1
# Selection mark is 'unselected' within bounding polygon '[0.257, 6.2358], [0.4542, 6.2358], [0.4542, 6.3955], [0.257, 6.3955]' and has a confidence of 0.1
# Selection mark is 'unselected' within bounding polygon '[0.2469, 6.6691], [0.4551, 6.6691], [0.4551, 6.7869], [0.2469, 6.7869]' and has a confidence of 0.1
# Selection mark is 'selected' within bounding polygon '[0.2526, 6.9462], [0.4525, 6.9462], [0.4525, 7.0814], [0.2526, 7.0814]' and has a confidence of 0.1
# Selection mark is 'unselected' within bounding polygon '[0.2535, 6.5339], [0.4557, 6.5339], [0.4557, 6.6533], [0.2535, 6.6533]' and has a confidence of 0.1
# Selection mark is 'selected' within bounding polygon '[0.2502, 6.085], [0.454, 6.085], [0.454, 6.2298], [0.2502, 6.2298]' and has a confidence of 0.1
# Selection mark is 'selected' within bounding polygon '[0.2569, 7.3277], [0.4461, 7.3277], [0.4461, 7.4769], [0.2569, 7.4769]' and has a confidence of 0.1
# Selection mark is 'selected' within bounding polygon '[0.2903, 7.1624], [0.445, 7.1624], [0.445, 7.2934], [0.2903, 7.2934]' and has a confidence of 0.1
# Selection mark is 'selected' within bounding polygon '[0.2555, 7.4136], [0.4545, 7.4136], [0.4545, 7.5621], [0.2555, 7.5621]' and has a confidence of 0.1
# Selection mark is 'selected' within bounding polygon '[0.2575, 5.7351], [0.4614, 5.7351], [0.4614, 5.8427], [0.2575, 5.8427]' and has a confidence of 0.1
# ----Detected #8 paragraphs in the document----
# -----Print sorted paragraphs-----
# Found paragraph with role: 'title' within
#  Page #1: [2.3607, 1.3742], [6.1502, 1.3717], [6.1506, 1.8995], [2.3611, 1.902] bounding region
# ...with content: 'Retrieval-Augmented Generation for Knowledge-Intensive NLP Tasks'
# ...with offset: 0 and length: 64
# Found paragraph with role: 'None' within
#  Page #1: [3.3273, 2.5007], [5.1706, 2.5017], [5.1705, 2.6553], [3.3272, 2.6543] bounding region
# ...with content: 'Patrick Lewis++, Ethan Perez*,'
# ...with offset: 65 and length: 30
# Found paragraph with role: 'None' within
#  Page #1: [1.5753, 2.8849], [7.1416, 2.8841], [7.1417, 3.9946], [1.5754, 3.9954] bounding region
# ...with content: 'Aleksandra Piktust, Fabio Petroni+, Vladimir Karpukhint, Naman Goyal+, Heinrich Küttler*, Mike Lewist, Wen-tau Yiht, Tim Rocktäschel++, Sebastian Riedel++, Douwe Kielat +Facebook AI Research; #University College London; * New York University; plewis@fb.com'
# ...with offset: 96 and length: 256
# Found paragraph with role: 'sectionHeading' within
#  Page #1: [3.9371, 4.3995], [4.5731, 4.3988], [4.5733, 4.5498], [3.9372, 4.5505] bounding region
# ...with content: 'Abstract'
# ...with offset: 353 and length: 8
# Found paragraph with role: 'None' within
#  Page #1: [1.9837, 4.7607], [6.5381, 4.7554], [6.5418, 7.947], [1.9874, 7.9523] bounding region
# ...with content: 'Large pre-trained language models have been shown to store factual knowledge in their parameters, and achieve state-of-the-art results when fine-tuned on down- stream NLP tasks. However, their ability to access and precisely manipulate knowl- edge is still limited, and hence on knowledge-intensive tasks, their performance lags behind task-specific architectures. Additionally, providing provenance for their decisions and updating their world knowledge remain open research problems. Pre- trained models with a differentiable access mechanism to explicit non-parametric memory have so far been only investigated for extractive downstream tasks. We explore a general-purpose fine-tuning recipe for retrieval-augmented generation (RAG) - models which combine pre-trained parametric and non-parametric mem- ory for language generation. We introduce RAG models where the parametric memory is a pre-trained seq2seq model and the non-parametric memory is a dense vector index of Wikipedia, accessed with a pre-trained neural retriever. We com- pare two RAG formulations, one which conditions on the same retrieved passages across the whole generated sequence, and another which can use different passages per token. We fine-tune and evaluate our models on a wide range of knowledge- intensive NLP tasks and set the state of the art on three open domain QA tasks, outperforming parametric seq2seq models and task-specific retrieve-and-extract architectures. For language generation tasks, we find that RAG models generate more specific, diverse and factual language than a state-of-the-art parametric-only seq2seq baseline.'
# ...with offset: 362 and length: 1618
# Found paragraph with role: 'sectionHeading' within
#  Page #1: [1.4996, 8.297], [2.6598, 8.3004], [2.6593, 8.4503], [1.4991, 8.4469] bounding region
# ...with content: '1 Introduction'
# ...with offset: 1981 and length: 14
# Found paragraph with role: 'None' within
#  Page #1: [1.4881, 8.6487], [7.0362, 8.6448], [7.0371, 10.0178], [1.4891, 10.0217] bounding region
# ...with content: 'Pre-trained neural language models have been shown to learn a substantial amount of in-depth knowl- edge from data [47]. They can do so without any access to an external memory, as a parameterized implicit knowledge base [51, 52]. While this development is exciting, such models do have down- sides: They cannot easily expand or revise their memory, can't straightforwardly provide insight into their predictions, and may produce "hallucinations" [38]. Hybrid models that combine parametric memory with non-parametric (i.e., retrieval-based) memories [20, 26, 48] can address some of these issues because knowledge can be directly revised and expanded, and accessed knowledge can be inspected and interpreted. REALM [20] and ORQA [31], two recently introduced models that combine masked language models [8] with a differentiable retriever, have shown promising results,'
# ...with offset: 1996 and length: 869
# Found paragraph with role: 'pageFooter' within
#  Page #1: [0.2237, 2.9535], [0.4922, 2.9532], [0.4968, 7.7849], [0.2283, 7.7851] bounding region
# ...with content: 'arXiv:2005.11401v4 [cs.CL] 12 Apr 2021'
# ...with offset: 2866 and length: 38
# ----------------------------------------

# %%
print(result)
# Out:
# {'apiVersion': '2024-11-30', 'modelId': 'prebuilt-layout', 'stringIndexType': 'textElements', 'content': 'Retrieval-Augmented Generation for Knowledge-Intensive NLP Tasks\nPatrick Lewis++, Ethan Perez*,\nAleksandra Piktust, Fabio Petroni+, Vladimir Karpukhint, Naman Goyal+, Heinrich Küttler*, Mike Lewist, Wen-tau Yiht, Tim Rocktäschel++, Sebastian Riedel++, Douwe Kielat +Facebook AI Research; #University College London; * New York University; plewis@fb.com\nAbstract\nLarge pre-trained language models have been shown to store factual knowledge in their parameters, and achieve state-of-the-art results when fine-tuned on down- stream NLP tasks. However, their ability to access and precisely manipulate knowl- edge is still limited, and hence on knowledge-intensive tasks, their performance lags behind task-specific architectures. Additionally, providing provenance for their decisions and updating their world knowledge remain open research problems. Pre- trained models with a differentiable access mechanism to explicit non-parametric memory have so far been only investigated for extractive downstream tasks. We explore a general-purpose fine-tuning recipe for retrieval-augmented generation (RAG) - models which combine pre-trained parametric and non-parametric mem- ory for language generation. We introduce RAG models where the parametric memory is a pre-trained seq2seq model and the non-parametric memory is a dense vector index of Wikipedia, accessed with a pre-trained neural retriever. We com- pare two RAG formulations, one which conditions on the same retrieved passages across the whole generated sequence, and another which can use different passages per token. We fine-tune and evaluate our models on a wide range of knowledge- intensive NLP tasks and set the state of the art on three open domain QA tasks, outperforming parametric seq2seq models and task-specific retrieve-and-extract architectures. For language generation tasks, we find that RAG models generate more specific, diverse and factual language than a state-of-the-art parametric-only seq2seq baseline.\n1 Introduction\nPre-trained neural language models have been shown to learn a substantial amount of in-depth knowl- edge from data [47]. They can do so without any access to an external memory, as a parameterized implicit knowledge base [51, 52]. While this development is exciting, such models do have down- sides: They cannot easily expand or revise their memory, can\'t straightforwardly provide insight into their predictions, and may produce "hallucinations" [38]. Hybrid models that combine parametric memory with non-parametric (i.e., retrieval-based) memories [20, 26, 48] can address some of these issues because knowledge can be directly revised and expanded, and accessed knowledge can be inspected and interpreted. REALM [20] and ORQA [31], two recently introduced models that combine masked language models [8] with a differentiable retriever, have shown promising results,\narXiv:2005.11401v4 [cs.CL] 12 Apr 2021 :unselected: :unselected: :unselected: :unselected: :selected: :unselected: :selected: :selected: :selected: :selected: :selected:', 'pages': [{'pageNumber': 1, 'angle': -0.019899999722838402, 'width': 8.5, 'height': 11, 'unit': 'inch', 'words': [{'content': 'Retrieval-Augmented', 'polygon': [2.3618, 1.3742, 4.5599, 1.375, 4.5592, 1.6276, 2.3609, 1.6253], 'confidence': 0.992, 'span': {'offset': 0, 'length': 19}}, {'content': 'Generation', 'polygon': [4.6303, 1.3752, 5.777, 1.3725, 5.7766, 1.6223, 4.6296, 1.6276], 'confidence': 0.995, 'span': {'offset': 20, 'length': 10}}, {'content': 'for', 'polygon': [5.8432, 1.3721, 6.1536, 1.372, 6.1536, 1.6201, 5.8428, 1.6222], 'confidence': 0.999, 'span': {'offset': 31, 'length': 3}}, {'content': 'Knowledge-Intensive', 'polygon': [2.5808, 1.6565, 4.7358, 1.6555, 4.7356, 1.8969, 2.5799, 1.9034], 'confidence': 0.992, 'span': {'offset': 35, 'length': 19}}, {'content': 'NLP', 'polygon': [4.8042, 1.6556, 5.2786, 1.6552, 5.2783, 1.894 ...
